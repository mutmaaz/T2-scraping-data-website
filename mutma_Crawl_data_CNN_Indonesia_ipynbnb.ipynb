# %% [markdown]
# <a href="https://colab.research.google.com/github/mutmaaz/T2-scraping-data-website/blob/main/mutma_Crawl_data_CNN_Indonesia_ipynbnb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install library yang dibutuhkan
# !pip install feedparser
# !pip install pandas
# !pip install openpyxl  # untuk export Excel

import feedparser
import pandas as pd
import json

# --- Pilih RSS feed CNN Indonesia ---
rss_urls = {
    "nasional": "https://www.cnnindonesia.com/nasional/rss",
    "internasional": "https://www.cnnindonesia.com/internasional/rss",
    "ekonomi": "https://www.cnnindonesia.com/ekonomi/rss",
    "teknologi": "https://www.cnnindonesia.com/tekno/rss",
    "olahraga": "https://www.cnnindonesia.com/olahraga/rss"
}

all_data = []

for kategori, rss_url in rss_urls.items():
    feed = feedparser.parse(rss_url)
    print(f"Kategori '{kategori}': Menemukan {len(feed.entries)} artikel.")

    for entry in feed.entries:
        all_data.append({
            "Kategori": kategori,
            "Judul": entry.title,
            "Link": entry.link,
            "Tanggal": entry.published
        })

valid_articles = len(all_data)
print(f"Berhasil mengumpulkan {valid_articles} artikel yang valid.")

# --- Simpan ke JSON ---
with open('list_post_cnn_lengkap.json', 'w', encoding='utf-8') as f:
    json.dump(all_data, f, ensure_ascii=False, indent=4)

# --- Simpan ke CSV ---
df = pd.DataFrame(all_data)
df.to_csv('list_post_cnn_lengkap.csv', index=False)

# --- Simpan ke Excel ---
df.to_excel('list_post_cnn_lengkap.xlsx', index=False)

print("Data berhasil diekspor ke list_post_cnn_lengkap.json")
print("Data berhasil diekspor ke list_post_cnn_lengkap.csv")
print("Data berhasil diekspor ke list_post_cnn_lengkap.xlsx")
# Out:
# Collecting feedparser
#   Downloading feedparser-6.0.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting sgmllib3k (from feedparser)
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
#   Preparing metadata (setup.py) ... done
# Downloading feedparser-6.0.12-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 2.0 MB/s eta 0:00:00
# Building wheels for collected packages: sgmllib3k
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6046 sha256=e13aaa23f4ff01fafaf47032f3da9a3d63b1b41022a418223cde6da33e100a08
#   Stored in directory: /root/.cache/pip/wheels/03/f5/1a/23761066dac1d0e8e683e5fdb27e12de53209d05a4a37e6246
# Successfully built sgmllib3k
# Installing collected packages: sgmllib3k, feedparser
# Successfully installed feedparser-6.0.12 sgmllib3k-1.0.0
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.12/dist-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl) (2.0.0)
# Kategori 'nasional': Menemukan 100 artikel.
# Kategori 'internasional': Menemukan 100 artikel.
# Kategori 'ekonomi': Menemukan 100 artikel.
# Kategori 'teknologi': Menemukan 0 artikel.
# Kategori 'olahraga': Menemukan 100 artikel.
# Berhasil mengumpulkan 400 artikel yang valid.
# Data berhasil diekspor ke list_post_cnn_lengkap.json
# Data berhasil diekspor ke list_post_cnn_lengkap.csv
# Data berhasil diekspor ke list_post_cnn_lengkap.xlsx

# %%
import pandas as pd

# Tentukan lokasi file CSV hasil scraping RSS CNN Indonesia
filename = "list_post_cnn_lengkap.csv"
file_path = filename

# Baca file CSV ke DataFrame
df = pd.read_csv(file_path, delimiter=",")

# Tampilkan DataFrame
display(df)
# Out:
#      Kategori                                              Judul  \
# 0    nasional    Mantan Dirut Asabri Adam Damiri Bakal Ajukan PK
# 1    nasional  Megawati Kesal Buzzer Sebar Kabar Dirinya Jual...
# 2    nasional  Kilang Minyak di Dumai Terbakar, Pertamina Buk...
# 3    nasional  Anggota Komisi III Minta Perusahaan Sawit Tak ...
# 4    nasional  Gempa M 6,1 Guncang Maluku Barat Daya, Tak Ber...
# ..        ...                                                ...
# 395  olahraga  Reaksi Pemain Vietnam Lihat Malaysia Dihukum FIFA
# 396  olahraga              Rooney Sudah Tak Percaya Amorim di MU
# 397  olahraga  Pecco Bagnaia 'Pimpin' Rombongan, Pembalap Mot...
# 398  olahraga  PSSI Yakin Dana Timnas Indonesia U-23 di SEA G...
# 399  olahraga  Erick Ungkap Perintah Khusus Prabowo di MotoGP...
#
#                                                   Link  \
# 0    https://www.cnnindonesia.com/nasional/20251001...
# 1    https://www.cnnindonesia.com/nasional/20251001...
# 2    https://www.cnnindonesia.com/nasional/20251001...
# 3    https://www.cnnindonesia.com/nasional/20251001...
# 4    https://www.cnnindonesia.com/nasional/20251001...
# ..                                                 ...
# 395  https://www.cnnindonesia.com/olahraga/20250930...
# 396  https://www.cnnindonesia.com/olahraga/20250929...
# 397  https://www.cnnindonesia.com/olahraga/20250929...
# 398  https://www.cnnindonesia.com/olahraga/20250929...
# 399  https://www.cnnindonesia.com/olahraga/20250929...
#
#                              Tanggal
# 0    Wed, 01 Oct 2025 23:32:38 +0700
# 1    Wed, 01 Oct 2025 23:15:35 +0700
# 2    Wed, 01 Oct 2025 22:54:54 +0700
# 3    Wed, 01 Oct 2025 22:40:56 +0700
# 4    Wed, 01 Oct 2025 22:00:04 +0700
# ..                               ...
# 395  Tue, 30 Sep 2025 02:00:37 +0700
# 396  Tue, 30 Sep 2025 01:00:50 +0700
# 397  Tue, 30 Sep 2025 00:00:37 +0700
# 398  Mon, 29 Sep 2025 23:31:00 +0700
# 399  Mon, 29 Sep 2025 23:02:25 +0700
#
# [400 rows x 4 columns]
